# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('political_parties_of_india.csv')

# %%
data.head()
# Out:
#     Assembly  State_Name                        Party_Name         Party_Type  \
# 0  Lok_Sabha  All_States                          CONGRESS     National Party
# 1  Lok_Sabha  All_States            Bharatiya Janata Party     National Party
# 2  Lok_Sabha  All_States  COMMUNIST MARXIST PARTY OF INDIA  State-based Party
# 3  Lok_Sabha  All_States                 Bharatiya Lok Dal     National Party
# 4  Lok_Sabha  All_States                        Janata Dal     National Party
#
#    Party_ID Frequent_Abbreviation Last_Abbreviation  \
# 0    3482.0                   INC               INC
# 1    1605.0                   BJP               BJP
# 2   14635.0                   CPM              CPIM
# 3    1711.0                   BLD               BLD
# 4    4217.0                    JD                JD
#
#                      Abbreviations  Start_Year  Last_Year  ...  \
# 0                       INC|INC(I)      1962.0     2019.0  ...
# ...

# %%
data.describe()
# Out:
#            Party_ID    Start_Year     Last_Year  No_Assemblies_Contested  \
# count  10147.000000  10152.000000  10152.000000             10153.000000
# mean    8931.680891   2002.806541   2008.163121                 2.029745
# std     6794.793013     15.641587     13.702433                 2.244093
# min        1.000000   1962.000000   1962.000000                 1.000000
# 25%     3952.000000   1996.000000   2000.000000                 1.000000
# 50%     7325.000000   2008.000000   2014.000000                 1.000000
# 75%    12103.000000   2014.000000   2019.000000                 2.000000
# max    25000.000000   2021.000000   2021.000000                15.000000
#
#        Candidates_Contested  Candidates_Represented  Females_Contested  \
# count          10153.000000            10153.000000       10153.000000
# mean              63.770905                6.963952           3.050133
# std              804.148604               71.572169          31.014447
# ...

# %%
data['Total_Years'] = data.Last_Year - data.Start_Year
data.dropna(axis='rows')
# Out:
#            Assembly   State_Name                        Party_Name  \
# 0         Lok_Sabha   All_States                          CONGRESS
# 1         Lok_Sabha   All_States            Bharatiya Janata Party
# 2         Lok_Sabha   All_States  COMMUNIST MARXIST PARTY OF INDIA
# 3         Lok_Sabha   All_States                 Bharatiya Lok Dal
# 4         Lok_Sabha   All_States                        Janata Dal
# ...             ...          ...                               ...
# 10126  Vidhan_Sabha  West_Bengal               Bharat Nirman Party
# 10127  Vidhan_Sabha  West_Bengal    Akhil Bhartiya Jharkhand Party
# 10128  Vidhan_Sabha  West_Bengal           Socialist Party (India)
# 10130  Vidhan_Sabha  West_Bengal            Nagaland Peoples Party
# 10152  Vidhan_Sabha  West_Bengal          Rashtravadi Janata Party
#
#               Party_Type  Party_ID Frequent_Abbreviation Last_Abbreviation  \
# 0         National Party    3482.0                   INC               INC
# ...

# %%
data.head()
# Out:
#     Assembly  State_Name                        Party_Name         Party_Type  \
# 0  Lok_Sabha  All_States                          CONGRESS     National Party
# 1  Lok_Sabha  All_States            Bharatiya Janata Party     National Party
# 2  Lok_Sabha  All_States  COMMUNIST MARXIST PARTY OF INDIA  State-based Party
# 3  Lok_Sabha  All_States                 Bharatiya Lok Dal     National Party
# 4  Lok_Sabha  All_States                        Janata Dal     National Party
#
#    Party_ID Frequent_Abbreviation Last_Abbreviation  \
# 0    3482.0                   INC               INC
# 1    1605.0                   BJP               BJP
# 2   14635.0                   CPM              CPIM
# 3    1711.0                   BLD               BLD
# 4    4217.0                    JD                JD
#
#                      Abbreviations  Start_Year  Last_Year  ...  \
# 0                       INC|INC(I)      1962.0     2019.0  ...
# ...

# %%
data[['Party_Name', 'Total_Years', 'Candidates_Represented', 'Party_Type']].sort_values(
    by=['Total_Years', 'Candidates_Represented'], ascending=False).dropna().iloc[:10]

# %%
data.Candidates_Represented.describe()
# Out:
# count    10153.000000
# mean         6.963952
# std         71.572169
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       3307.000000
# Name: Candidates_Represented, dtype: float64
